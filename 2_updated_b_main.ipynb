# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('data_updated_clean_2.csv')
data.head()
# Out:
#    Unnamed: 0            Timestamp  Age Gender   Education       Living_Area  \
# 0           0  18/09/2022 19:41:35   26   Male  Bachelor's  Urban(Town,City)
# 1           1  18/09/2022 20:02:19   23   Male  Bachelor's  Urban(Town,City)
# 2           2  19/09/2022 12:31:29   23   Male  Bachelor's  Urban(Town,City)
# 3           3  19/09/2022 12:34:08   23   Male    Master's  Urban(Town,City)
# 4           4  19/09/2022 12:45:44   24   Male  Bachelor's  Urban(Town,City)
#
#   Marital_Status Family_Type Coronavirus  1s  ...  18s  19a  20a  21d  \
# 0      Unmarried      Single         Yes   1  ...    0    1    2    3
# 1      Unmarried      Single         Yes   1  ...    2    1    1    2
# 2      Unmarried      Single          No   0  ...    0    0    0    0
# 3      Unmarried       Joint         Yes   2  ...    2    1    2    3
# 4      Unmarried      Single          No   1  ...    1    1    0    0
#
#    total_depression  depression_state  total_anxiety  anxiety_state  \
# 0                18                 1             20              1
# 1                16                 1             18              1
# 2                 4                 0              8              1
# 3                26                 1             26              1
# 4                 6                 0              6              0
#
#    total_stress  stress_state
# 0            12             0
# 1            28             1
# 2             6             0
# 3            32             1
# 4             8             0
#
# [5 rows x 36 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'depression_state', data = data)
# Out:
# <AxesSubplot:xlabel='depression_state', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'anxiety_state', data = data)
# Out:
# <AxesSubplot:xlabel='anxiety_state', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'stress_state', data = data)
# Out:
# <AxesSubplot:xlabel='stress_state', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
 

data['Age'] = le.fit_transform(data['Age'])
data['Gender'] = le.fit_transform(data['Gender'])
data['Education'] = le.fit_transform(data['Education'])
data['Living_Area'] = le.fit_transform(data['Living_Area'])
data['Marital_Status'] = le.fit_transform(data['Marital_Status'])
data['Family_Type'] = le.fit_transform(data['Family_Type'])
data['Coronavirus'] = le.fit_transform(data['Coronavirus'])

# %%
depression = data[['3d', '5d', '10d', '13d', '16d', '17d','21d','depression_state']]
anxiety = data[['2a', '4a', '7a', '9a', '15a', '19a','20a','anxiety_state']]
stress = data[['1s', '6s', '8s', '11s', '12s', '14s','18s','stress_state']]

# %%
depression_correlation=depression.corr()
print(depression_correlation['depression_state'].sort_values(ascending=False))
# Out:
# depression_state    1.000000
# 21d                 0.591706
# 16d                 0.589477
# 10d                 0.582772
# 13d                 0.556251
# 17d                 0.553786
# 5d                  0.540367
# 3d                  0.496832
# Name: depression_state, dtype: float64

# %%
depression_correlation
# Out:
#                         3d        5d       10d       13d       16d       17d  \
# 3d                1.000000  0.521387  0.504767  0.508563  0.426965  0.459265
# 5d                0.521387  1.000000  0.525473  0.419683  0.411761  0.335816
# 10d               0.504767  0.525473  1.000000  0.616596  0.606690  0.538938
# 13d               0.508563  0.419683  0.616596  1.000000  0.536643  0.486526
# 16d               0.426965  0.411761  0.606690  0.536643  1.000000  0.492049
# 17d               0.459265  0.335816  0.538938  0.486526  0.492049  1.000000
# 21d               0.447498  0.407137  0.525779  0.456981  0.482860  0.582497
# depression_state  0.496832  0.540367  0.582772  0.556251  0.589477  0.553786
#
#                        21d  depression_state
# 3d                0.447498          0.496832
# 5d                0.407137          0.540367
# 10d               0.525779          0.582772
# 13d               0.456981          0.556251
# 16d               0.482860          0.589477
# 17d               0.582497          0.553786
# 21d               1.000000          0.591706
# depression_state  0.591706          1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(depression_correlation,annot=True,cmap='Blues',square=True,vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
anxiety_correlation=anxiety.corr()
print(anxiety_correlation['anxiety_state'].sort_values(ascending=False))
# Out:
# anxiety_state    1.000000
# 15a              0.618167
# 20a              0.580864
# 9a               0.577998
# 19a              0.572068
# 4a               0.516150
# 7a               0.500283
# 2a               0.474222
# Name: anxiety_state, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(anxiety_correlation,annot=True,cmap='Greens',square=True,vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
stress_correlation=stress.corr()
print(stress_correlation['stress_state'].sort_values(ascending=False))
# Out:
# stress_state    1.000000
# 8s              0.648625
# 12s             0.648260
# 18s             0.630462
# 11s             0.586664
# 14s             0.580736
# 6s              0.534461
# 1s              0.472734
# Name: stress_state, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(stress_correlation,annot=True,cmap='BuPu',square=True,vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
X_depression = data[['3d', '5d', '10d', '13d', '16d', '17d','21d']]
Y_depression = data['depression_state']


X_anxiety = data[['2a', '4a', '7a', '9a', '15a', '19a','20a']]
Y_anxiety = data['anxiety_state']


X_stress = data[['1s', '6s', '8s', '11s', '12s', '14s','18s']]
Y_stress = data['stress_state']

# %%
from sklearn.model_selection import train_test_split


X_train_d, X_test_d, y_train_d, y_test_d = train_test_split(X_depression, Y_depression, test_size = 0.2, random_state = 42)
X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(X_anxiety, Y_anxiety, test_size = 0.2, random_state = 42)
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_stress, Y_stress, test_size = 0.2, random_state = 42)


print("Train Set: ", X_train_d.shape, y_train_d.shape)
print("Test Set: ", X_test_d.shape, y_test_d.shape)
# Out:
# Train Set:  (407, 7) (407,)
# Test Set:  (102, 7) (102,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

# %%
RANDOM_STATE = 42

model_params = {
    
    'SVC': {
        'model': SVC(random_state=RANDOM_STATE),
        'params' : {
            'kernel': ['rbf'],
            'C': [0.1, 1, 10, 100],
            'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                      
        }  
    },
    
    
    'random_forest': {
        'model': RandomForestClassifier(max_depth=7, min_samples_split=5, min_samples_leaf=5, random_state=RANDOM_STATE),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    
    
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    
    
    'naive_bayes_multinomial': {
        'model': MultinomialNB(),
        'params': {}
    },
    
    'K-nearest neighbors': {
        'model': KNeighborsClassifier(),
        'params': {}
    },
    
    
    'Gradient boosting classifiers': {
        'model': GradientBoostingClassifier(
                   learning_rate=0.005, n_estimators=30, random_state=RANDOM_STATE),
        'params': {
            'learning_rate': [0.001, 0.01, 0.005],
            'n_estimators': [10,20,30]
        }
    },
    
    
    'decision_tree': {
        'model': DecisionTreeClassifier(max_depth=2, random_state=RANDOM_STATE),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }
    
}

# %%
from sklearn.model_selection import GridSearchCV

scores_d = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train_d, y_train_d)
    scores_d.append({
        'Model': model_name,
        'Accuracy': clf.best_score_,
        'best_params': clf.best_params_
    })
    
result_d = pd.DataFrame(scores_d,columns=['Model','Accuracy','best_params'])

result_d
# Out:
#                            Model  Accuracy  \
# 0                            SVC  1.000000
# 1                  random_forest  0.943511
# 2            logistic_regression  1.000000
# 3        naive_bayes_multinomial  0.678169
# 4            K-nearest neighbors  0.985245
# 5  Gradient boosting classifiers  0.719904
# 6                  decision_tree  0.884523
#
#                                     best_params        f1
# 0     {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}  1.000000
# 1                          {'n_estimators': 10}  0.958333
# 2                                      {'C': 5}  1.000000
# 3                                            {}  0.809524
# 4                                            {}  0.985915
# 5  {'learning_rate': 0.001, 'n_estimators': 10}  0.827586
# 6                         {'criterion': 'gini'}  0.937931

# %%
classifierDep = SVC(C=1,gamma=1, kernel='rbf', random_state=RANDOM_STATE)
classifierDep.fit(X_train_d, y_train_d)
# Out:
# SVC(C=1, gamma=1, random_state=42)

# %%
y_pred_d = classifierDep.predict(X_test_d)
print(f"Train Accuracy for Depressoion is: {round(classifierDep.score(X_train_d, y_train_d)*100,2)}%")
print(f"Test Accuracy Depressoion is : {round(classifierDep.score(X_test_d, y_test_d)*100,2)}%")
print('Cross Validation Depressoion Score:',round(np.mean(cross_val_score(classifierDep, X_train_d, y_train_d, cv = 5)),3))
# Out:
# Train Accuracy for Depressoion is: 100.0%
# Test Accuracy Depressoion is : 99.02%
# Cross Validation Depressoion Score: 0.978

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_d,y_pred_d))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        30
#            1       0.99      1.00      0.99        72
#
#     accuracy                           0.99       102
#    macro avg       0.99      0.98      0.99       102
# weighted avg       0.99      0.99      0.99       102

# %%
conf_mat = confusion_matrix(y_test_d,y_pred_d)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="Blues")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot
fig, (ax2) = plt.subplots(figsize = (8,6))

fpr, tpr, thresholds_roc = roc_curve(y_test_d,y_pred_d)
roc_auc = auc(fpr,tpr)
ax2.plot(fpr,tpr, label = " AUROC = {:0.2f}".format(roc_auc))
ax2.plot([0,1], [0,1], 'r', linestyle = "--", lw = 2)
ax2.set_xlabel("False Positive Rate", fontsize = 14)
ax2.set_ylabel("True Positive Rate", fontsize = 14)
ax2.set_title("ROC Curve", fontsize = 18)
ax2.legend(loc = 'best')
plt.title('ROC curve for Support Vector Classifier (Depression)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

close_default = np.argmin(np.abs(thresholds_roc - 0.5))
ax2.plot(fpr[close_default], tpr[close_default], 'o', markersize = 8)
plt.tight_layout()

# %%
scores_a = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train_a, y_train_a)
    scores_a.append({
        'Model': model_name,
        'Accuracy': clf.best_score_,
        'best_params': clf.best_params_
    })
    
result_a = pd.DataFrame(scores_a,columns=['Model','Accuracy','best_params'])

result_a
# Out:
#                            Model  Accuracy  \
# 0                            SVC  1.000000
# 1                  random_forest  0.955736
# 2            logistic_regression  0.995122
# 3        naive_bayes_multinomial  0.629148
# 4            K-nearest neighbors  0.953418
# 5  Gradient boosting classifiers  0.859952
# 6                  decision_tree  0.889461
#
#                                    best_params
# 0   {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 1                         {'n_estimators': 10}
# 2                                    {'C': 10}
# 3                                           {}
# 4                                           {}
# 5  {'learning_rate': 0.01, 'n_estimators': 30}
# 6                        {'criterion': 'gini'}

# %%
classifierAnx = SVC(C=1,gamma=1, kernel='rbf', random_state=RANDOM_STATE)
classifierAnx.fit(X_train_a, y_train_a)
# Out:
# SVC(C=1, gamma=1, random_state=42)

# %%
y_pred_a = classifierAnx.predict(X_test_a)
print(f"Train Accuracy for Anxiety is: {round(classifierAnx.score(X_train_a, y_train_a)*100,2)}%")
print(f"Test Accuracy Anxiety is : {round(classifierAnx.score(X_test_a, y_test_a)*100,2)}%")
print('Cross Validation Anxiety Score:',round(np.mean(cross_val_score(classifierAnx, X_train_a, y_train_a, cv = 5)),3))
# Out:
# Train Accuracy for Anxiety is: 99.75%
# Test Accuracy Anxiety is : 98.04%
# Cross Validation Anxiety Score: 0.973

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_a,y_pred_a))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        26
#            1       0.99      0.99      0.99        76
#
#     accuracy                           0.98       102
#    macro avg       0.97      0.97      0.97       102
# weighted avg       0.98      0.98      0.98       102

# %%
conf_mat = confusion_matrix(y_test_a,y_pred_a)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="Greens")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot
fig, (ax2) = plt.subplots(figsize = (8,6))

fpr, tpr, thresholds_roc = roc_curve(y_test_a,y_pred_a)
roc_auc = auc(fpr,tpr)
ax2.plot(fpr,tpr, label = " AUROC = {:0.2f}".format(roc_auc))
ax2.plot([0,1], [0,1], 'r', linestyle = "--", lw = 2)
ax2.set_xlabel("False Positive Rate", fontsize = 14)
ax2.set_ylabel("True Positive Rate", fontsize = 14)
ax2.set_title("ROC Curve", fontsize = 18)
ax2.legend(loc = 'best')
plt.title('ROC curve for Support Vector Classifier (Anxiety)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

close_default = np.argmin(np.abs(thresholds_roc - 0.5))
ax2.plot(fpr[close_default], tpr[close_default], 'o', markersize = 8)
plt.tight_layout()

# %%
scores_s = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train_s, y_train_s)
    scores_s.append({
        'Model': model_name,
        'Accuracy': clf.best_score_,
        'best_params': clf.best_params_
    })
    
result_s = pd.DataFrame(scores_s,columns=['Model','Accuracy','best_params'])

result_s
# Out:
#                            Model  Accuracy  \
# 0                            SVC  1.000000
# 1                  random_forest  0.919030
# 2            logistic_regression  0.995092
# 3        naive_bayes_multinomial  0.552695
# 4            K-nearest neighbors  0.941072
# 5  Gradient boosting classifiers  0.899368
# 6                  decision_tree  0.867510
#
#                                    best_params
# 0   {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 1                         {'n_estimators': 10}
# 2                                     {'C': 5}
# 3                                           {}
# 4                                           {}
# 5  {'learning_rate': 0.01, 'n_estimators': 30}
# 6                        {'criterion': 'gini'}

# %%
classifierStr = SVC(C=10,gamma=0.01, kernel='rbf', random_state=RANDOM_STATE)
classifierStr.fit(X_train_s, y_train_s)
# Out:
# SVC(C=10, gamma=0.01, random_state=42)

# %%
y_pred_s = classifierStr.predict(X_test_s)
print(f"Train Accuracy for Stress is: {round(classifierStr.score(X_train_s, y_train_s)*100,2)}%")
print(f"Test Accuracy Stress is : {round(classifierStr.score(X_test_s, y_test_s)*100,2)}%")
print('Cross Validation Stress Score:',round(np.mean(cross_val_score(classifierStr, X_train_s, y_train_s, cv = 5)),3))
# Out:
# Train Accuracy for Stress is: 99.75%
# Test Accuracy Stress is : 97.06%
# Cross Validation Stress Score: 0.99

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_s,y_pred_s))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        47
#            1       0.98      0.96      0.97        55
#
#     accuracy                           0.97       102
#    macro avg       0.97      0.97      0.97       102
# weighted avg       0.97      0.97      0.97       102

# %%
conf_mat = confusion_matrix(y_test_s,y_pred_s)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="BuPu")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from matplotlib import pyplot
fig, (ax2) = plt.subplots(figsize = (8,6))

fpr, tpr, thresholds_roc = roc_curve(y_test_s,y_pred_s)
roc_auc = auc(fpr,tpr)
ax2.plot(fpr,tpr, label = " AUROC = {:0.2f}".format(roc_auc))
ax2.plot([0,1], [0,1], 'r', linestyle = "--", lw = 2)
ax2.set_xlabel("False Positive Rate", fontsize = 14)
ax2.set_ylabel("True Positive Rate", fontsize = 14)
ax2.set_title("ROC Curve", fontsize = 18)
ax2.legend(loc = 'best')
plt.title('ROC curve for Support Vector Classifier (Stress)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

close_default = np.argmin(np.abs(thresholds_roc - 0.5))
ax2.plot(fpr[close_default], tpr[close_default], 'o', markersize = 8)
plt.tight_layout()
